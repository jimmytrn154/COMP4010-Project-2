# %%
import pandas as pd

# %%
df = pd.read_csv('mekong_province_day_rainfall_1981_2025.csv')
df.head()
# Out:
#   province_name        date  year  month  day  rainfall_mm
# 0     Soc Trang  1981-01-01  1981      1    1          0.0
# 1      Tra Vinh  1981-01-01  1981      1    1          0.0
# 2     Vinh Long  1981-01-01  1981      1    1          0.0
# 3      Bac Lieu  1981-01-01  1981      1    1          0.0
# 4        Ca Mau  1981-01-01  1981      1    1          0.0

# %%
df.shape
# Out:
# (213668, 6)
